# %%
import pandas as pd 

df = pd.read_csv("C:/Users/Stanislav/OneDrive/Pulpit/Data Science and Licencjat/Licencjat/Dane/HANZE_european_floods_losses/HANZE_events.csv")
df.head()
# Out:
#      ID Country code  Year Country name  Start date    End date   Type  \
# 0  2000           AL  1946      Albania  1946-10-11  1946-11-15  River
# 1  2001           AL  1953      Albania  1953-12-12  1953-12-12  Flash
# 2  2002           AL  1960      Albania  1960-11-07  1960-11-07  Flash
# 3  2003           AL  1962      Albania  1962-11-15  1962-11-16  River
# 4  2532           AL  1968      Albania  1968-12-17  1968-12-17  Flash
#
#                 Flood source  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3  Drin; Buna; Semani; Vjosa
# 4                        NaN
#
#                             Regions affected (v2010)  \
# 0  AL011;AL012;AL013;AL015;AL021;AL022;AL031;AL03...
# 1                                        AL014;AL015
# 2                                  AL022;AL032;AL035
# 3  AL011;AL012;AL013;AL014;AL015;AL021;AL022;AL03...
# 4                                              AL015
#
# ...

# %%
print(df['Losses (nominal value)'].isna().sum())
print(df.info)
# Out:
# 1516
# <bound method DataFrame.info of         ID Country code  Year    Country name  Start date    End date   Type  \
# 0     2000           AL  1946         Albania  1946-10-11  1946-11-15  River
# 1     2001           AL  1953         Albania  1953-12-12  1953-12-12  Flash
# 2     2002           AL  1960         Albania  1960-11-07  1960-11-07  Flash
# 3     2003           AL  1962         Albania  1962-11-15  1962-11-16  River
# 4     2532           AL  1968         Albania  1968-12-17  1968-12-17  Flash
# ...    ...          ...   ...             ...         ...         ...    ...
# 2516  2342           UK  2019  United Kingdom  2019-11-07  2019-11-09  River
# 2517  2343           UK  2020  United Kingdom  2020-02-08  2020-02-10  River
# 2518  2344           UK  2020  United Kingdom  2020-02-15  2020-02-18  River
# 2519  2688           UK  2020  United Kingdom  2020-08-11  2020-08-12  Flash
# 2520  2345           UK  2020  United Kingdom  2020-12-18  2020-12-28  River
#
# ...

# %%
df[df['Fatalities'] == 0.0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 4 to 2520
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          907 non-null    int64
#  1   Country code                907 non-null    object
#  2   Year                        907 non-null    int64
#  3   Country name                907 non-null    object
#  4   Start date                  907 non-null    object
#  5   End date                    907 non-null    object
#  6   Type                        907 non-null    object
#  7   Flood source                630 non-null    object
#  8   Regions affected (v2010)    907 non-null    object
#  9   Regions affected (v2021)    907 non-null    object
#  10  Area flooded                211 non-null    float64
#  11  Fatalities                  907 non-null    float64
#  12  Persons affected            551 non-null    float64
# ...
