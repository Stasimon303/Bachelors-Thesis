# %%
   import numpy as np
   from PIL import Image
   import matplotlib.pyplot as plt

   # Otwórz obraz
   im = Image.open("C:/Users/Stanislav/OneDrive/Pulpit/Data Science and Licencjat/Licencjat/Dane/Brazos_hydraulic_simulation/flood.tif")

   # Konwersja do tablicy NumPy
   imarray = np.array(im)

   # Wizualizacja danych
   plt.imshow(imarray, cmap='plasma')  # Możesz wybrać różne kolory np. 'viridis', 'plasma'

   plt.title('Flooded area')
   plt.show()

# %%
 # Otwórz obraz
im2 = Image.open("C:/Users/Stanislav/OneDrive/Pulpit/Data Science and Licencjat/Licencjat/Dane/Brazos_hydraulic_simulation/dtm.tif")

# Konwersja do tablicy NumPy
imarray = np.array(im2)

# Wizualizacja danych
plt.imshow(imarray, cmap='plasma')  # Możesz wybrać różne kolory np. 'viridis', 'plasma'
plt.colorbar(label='Height (?)')
plt.title('Digital Terrain Model (?)')
plt.show()

# %%
# Otwórz obraz
im3 = Image.open("C:/Users/Stanislav/OneDrive/Pulpit/Data Science and Licencjat/Licencjat/Dane/Brazos_hydraulic_simulation/brazos_basement_water_level.tif")

# Konwersja do tablicy NumPy
imarray = np.array(im3)

# Wizualizacja danych
plt.imshow(imarray, cmap='plasma')  # Możesz wybrać różne kolory np. 'viridis', 'plasma'
plt.colorbar(label='(?)')
plt.title('Water basement level')
plt.show()

# %%
# Otwórz obraz
im4 = Image.open("C:/Users/Stanislav/OneDrive/Pulpit/Data Science and Licencjat/Licencjat/Dane/Brazos_hydraulic_simulation/brazos_basement_water_depth.tif")

# Konwersja do tablicy NumPy
imarray = np.array(im4)

# Wizualizacja danych
plt.imshow(imarray, cmap='plasma')  # Możesz wybrać różne kolory np. 'viridis', 'plasma'
plt.colorbar(label='Water Depth')
plt.title('Water depth level')
plt.show()
